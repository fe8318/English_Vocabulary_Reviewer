# %%
# !pyinstaller --onefile --windowed 單字管理器.py
# Out:
# 1265 INFO: PyInstaller: 6.14.0, contrib hooks: 2025.4
# 1265 INFO: Python: 3.12.7 (conda)
# 1286 INFO: Platform: Windows-11-10.0.26100-SP0
# 1286 INFO: Python environment: C:\Users\user\anaconda3
# 1287 INFO: wrote C:\Users\user\Documents\英文答題系統\單字管理器.spec
# 1288 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\user\\anaconda3\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\user\\anaconda3\\python312.zip',
#  'C:\\Users\\user\\anaconda3\\DLLs',
#  'C:\\Users\\user\\anaconda3\\Lib',
#  'C:\\Users\\user\\anaconda3',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages\\win32',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages\\Pythonwin',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages\\setuptools\\_vendor',
#  'C:\\Users\\user\\Documents\\英文答題系統']
# 2807 INFO: checking Analysis
# 2807 INFO: Building Analysis because Analysis-00.toc is non existent
# ...

# %%
# !pyinstaller --clean --onefile --windowed 單字管理器.py
# Out:
# 1325 INFO: PyInstaller: 6.14.0, contrib hooks: 2025.4
# 1325 INFO: Python: 3.12.7 (conda)
# 1349 INFO: Platform: Windows-11-10.0.26100-SP0
# 1349 INFO: Python environment: C:\Users\user\anaconda3
# 1350 INFO: wrote C:\Users\user\Documents\英文答題系統\單字管理器.spec
# 1351 INFO: Removing temporary files and cleaning cache in C:\Users\user\AppData\Local\pyinstaller
# 1352 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\user\\anaconda3\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\user\\anaconda3\\python312.zip',
#  'C:\\Users\\user\\anaconda3\\DLLs',
#  'C:\\Users\\user\\anaconda3\\Lib',
#  'C:\\Users\\user\\anaconda3',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages\\win32',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages\\Pythonwin',
#  'C:\\Users\\user\\anaconda3\\Lib\\site-packages\\setuptools\\_vendor',
#  'C:\\Users\\user\\Documents\\英文答題系統']
# ...
